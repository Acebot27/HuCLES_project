# %% [markdown]
# # HuCLES (Human Confidence Level Evaluation System)
#
# This project is about proposing a system which will evaluate an individual’s confidence level by observing their behavior and approaches when they will be giving an interview.
#
# This system will not only help others for evaluating an individual but also might help the individual to keep a check on their own confidence level while going through such important evaluation process which will help them later to improve themselves for such situations.
#
# ### - Classification of Confidence Level
#
# - In this system, a human’s confidence level will be evaluated based on their facial expressions, head or body gestures which the system will observe through a video while they were giving their interviews or exams.
#
#     The system will evaluate an individual’s confidence level from their gestures like nodding head positively or in confusion, speed of their hand movements, fluidity and other body gesture which indicates the confidence in them. It will also analysis the individual’s facial expression throughout to look for confidence level in them using some emotion analysis as well and then it will convey theirs overall confidence level to them by integrating all these above two evaluation together.
#
#         We are classifying the confidence into following 7 levels based on the analysis of above mentioned body   language cues of the person
# <img src="CLevels.png">

# %% [markdown]
# # Implementation -
#
# ## 1. Loading the data
# Here, we load the dataset and split it into training and testing data

# %%
from code_scripts import prepareFData as ppFD
# Out:
# Using TensorFlow backend.
# T:\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# T:\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# T:\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# T:\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# T:\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# T:\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
dataset_path = "./face/fer2013.csv" 
train_data, train_labels, test_data, test_labels = ppFD.load_data(dataset_path)

print("Number of images in Training set:", len(train_data))
print("Number of images in Test set:", len(test_data))
# Out:
# Number of images in Training set: 32298
# Number of images in Test set: 3589

# %% [markdown]
# ## 2. Defining and Deploying CNN for training the model
# We have built ourselves a Convolutional Neural Network which has convolutional layers armed with filters that extract features out of images.
#
# We have used Keras to deploy our neural network and also have used Dropout layers frequently since Dropout layers inhibit overfitting by randomly dropping out units from the neural network.
#
# We will use 20 percent of the training data as validation data.

# %%
# CNN model package
from code_scripts import modelCNN as md

# %%
# Hyperparameters
epochs = 120
batch_size = 64
learning_rate = 0.001

# defining model
model = md.createCNN(learning_rate)

# Callbacks
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, TensorBoard, ModelCheckpoint

lr_reducer = ReduceLROnPlateau(monitor='val_loss', factor=0.9, patience=3)
early_stopper = EarlyStopping(monitor='val_acc', min_delta=0, patience=6, mode='auto')
checkpointer = ModelCheckpoint('./model/weights.hd5', monitor='val_loss', verbose=1, save_best_only=True)
# Out:
# WARNING:tensorflow:From T:\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 46, 46, 64)        640
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 46, 46, 64)        36928
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 46, 46, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 23, 23, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 23, 23, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 23, 23, 128)       73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 23, 23, 128)       512
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 23, 23, 128)       147584
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 23, 23, 128)       512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 23, 23, 128)       147584
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 23, 23, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 11, 11, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 11, 11, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 11, 11, 256)       295168
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 11, 11, 256)       1024
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 11, 11, 256)       590080
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 11, 11, 256)       1024
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 11, 11, 256)       590080
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 11, 11, 256)       1024
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 256)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 5, 5, 256)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 5, 5, 512)         1180160
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 5, 5, 512)         2048
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 5, 5, 512)         2359808
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 5, 5, 512)         2048
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 5, 5, 512)         2359808
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 5, 5, 512)         2048
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 7)                 455
# =================================================================
# Total params: 9,014,727
# Trainable params: 9,009,223
# Non-trainable params: 5,504
# _________________________________________________________________
# None

# %%
# training(or compiling/deploying) the model
model = md.compileCNN(model, train_data, train_labels, epochs, batch_size, lr_reducer, checkpointer, early_stopper)
# Out:
# WARNING:tensorflow:From T:\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 25838 samples, validate on 6460 samples
# Epoch 1/120
# 25838/25838 [==============================] - 59s 2ms/step - loss: 2.1630 - accuracy: 0.1974 - val_loss: 1.8799 - val_accuracy: 0.2489
#
# Epoch 00001: val_loss improved from inf to 1.87986, saving model to ./model/weights.hd5
# Epoch 2/120
#    64/25838 [..............................] - ETA: 51s - loss: 1.8442 - accuracy: 0.2344
# T:\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:846: RuntimeWarning: Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: val_loss,val_accuracy,loss,accuracy,lr
#   (self.monitor, ','.join(list(logs.keys()))), RuntimeWarning
# 25838/25838 [==============================] - 54s 2ms/step - loss: 1.8609 - accuracy: 0.2331 - val_loss: 1.8423 - val_accuracy: 0.2489
#
# Epoch 00002: val_loss improved from 1.87986 to 1.84230, saving model to ./model/weights.hd5
# Epoch 3/120
# 25838/25838 [==============================] - 54s 2ms/step - loss: 1.8416 - accuracy: 0.2437 - val_loss: 1.8306 - val_accuracy: 0.2489
#
# Epoch 00003: val_loss improved from 1.84230 to 1.83058, saving model to ./model/weights.hd5
# Epoch 4/120
# 25838/25838 [==============================] - 55s 2ms/step - loss: 1.8334 - accuracy: 0.2464 - val_loss: 1.8252 - val_accuracy: 0.2489
#
# Epoch 00004: val_loss improved from 1.83058 to 1.82525, saving model to ./model/weights.hd5
# Epoch 5/120
# 25838/25838 [==============================] - 55s 2ms/step - loss: 1.8264 - accuracy: 0.2487 - val_loss: 1.8152 - val_accuracy: 0.2489
#
# Epoch 00005: val_loss improved from 1.82525 to 1.81519, saving model to ./model/weights.hd5
# Epoch 6/120
# 25838/25838 [==============================] - 56s 2ms/step - loss: 1.8188 - accuracy: 0.2502 - val_loss: 1.8120 - val_accuracy: 0.2489
#
# Epoch 00006: val_loss improved from 1.81519 to 1.81200, saving model to ./model/weights.hd5
# Epoch 7/120
# 25838/25838 [==============================] - 57s 2ms/step - loss: 1.8129 - accuracy: 0.2513 - val_loss: 1.8079 - val_accuracy: 0.2489
#
# Epoch 00007: val_loss improved from 1.81200 to 1.80791, saving model to ./model/weights.hd5
# Epoch 8/120
# 25838/25838 [==============================] - 58s 2ms/step - loss: 1.8095 - accuracy: 0.2504 - val_loss: 1.8029 - val_accuracy: 0.2489
#
# Epoch 00008: val_loss improved from 1.80791 to 1.80292, saving model to ./model/weights.hd5
# Epoch 9/120
# 25838/25838 [==============================] - 59s 2ms/step - loss: 1.8046 - accuracy: 0.2501 - val_loss: 1.8193 - val_accuracy: 0.2489
#
# Epoch 00009: val_loss did not improve from 1.80292
# Epoch 10/120
# 25838/25838 [==============================] - 62s 2ms/step - loss: 1.7981 - accuracy: 0.2545 - val_loss: 1.7815 - val_accuracy: 0.2489
#
# Epoch 00010: val_loss improved from 1.80292 to 1.78148, saving model to ./model/weights.hd5
# Epoch 11/120
# 25838/25838 [==============================] - 60s 2ms/step - loss: 1.7721 - accuracy: 0.2728 - val_loss: 1.7611 - val_accuracy: 0.2628
#
# Epoch 00011: val_loss improved from 1.78148 to 1.76113, saving model to ./model/weights.hd5
# Epoch 12/120
# 25838/25838 [==============================] - 60s 2ms/step - loss: 1.7292 - accuracy: 0.2958 - val_loss: 1.6969 - val_accuracy: 0.3028
#
# Epoch 00012: val_loss improved from 1.76113 to 1.69690, saving model to ./model/weights.hd5
# Epoch 13/120
# 25838/25838 [==============================] - 60s 2ms/step - loss: 1.6637 - accuracy: 0.3177 - val_loss: 1.5707 - val_accuracy: 0.3658
#
# Epoch 00013: val_loss improved from 1.69690 to 1.57074, saving model to ./model/weights.hd5
# Epoch 14/120
# 25838/25838 [==============================] - 60s 2ms/step - loss: 1.5791 - accuracy: 0.3678 - val_loss: 1.5131 - val_accuracy: 0.4067
#
# Epoch 00014: val_loss improved from 1.57074 to 1.51312, saving model to ./model/weights.hd5
# Epoch 15/120
# 25838/25838 [==============================] - 60s 2ms/step - loss: 1.5270 - accuracy: 0.3947 - val_loss: 1.5597 - val_accuracy: 0.3743
#
# Epoch 00015: val_loss did not improve from 1.51312
# Epoch 16/120
# 25838/25838 [==============================] - 61s 2ms/step - loss: 1.4914 - accuracy: 0.4104 - val_loss: 1.4733 - val_accuracy: 0.4071
#
# Epoch 00016: val_loss improved from 1.51312 to 1.47331, saving model to ./model/weights.hd5
# Epoch 17/120
# 25838/25838 [==============================] - 60s 2ms/step - loss: 1.4595 - accuracy: 0.4213 - val_loss: 1.4746 - val_accuracy: 0.4122
#
# Epoch 00017: val_loss did not improve from 1.47331
# Epoch 18/120
# 25838/25838 [==============================] - 62s 2ms/step - loss: 1.4376 - accuracy: 0.4272 - val_loss: 1.3549 - val_accuracy: 0.4311
#
# Epoch 00018: val_loss improved from 1.47331 to 1.35495, saving model to ./model/weights.hd5
# Epoch 19/120
# 25838/25838 [==============================] - 61s 2ms/step - loss: 1.4188 - accuracy: 0.4320 - val_loss: 1.4523 - val_accuracy: 0.4127
#
# Epoch 00019: val_loss did not improve from 1.35495
# Epoch 20/120
# 25838/25838 [==============================] - 61s 2ms/step - loss: 1.4072 - accuracy: 0.4365 - val_loss: 1.3415 - val_accuracy: 0.4585
#
# Epoch 00020: val_loss improved from 1.35495 to 1.34153, saving model to ./model/weights.hd5
# Epoch 21/120
# 25838/25838 [==============================] - 61s 2ms/step - loss: 1.3810 - accuracy: 0.4428 - val_loss: 1.3624 - val_accuracy: 0.4449
#
# Epoch 00021: val_loss did not improve from 1.34153
# Epoch 22/120
# 25838/25838 [==============================] - 61s 2ms/step - loss: 1.3746 - accuracy: 0.4469 - val_loss: 1.3360 - val_accuracy: 0.4526
#
# Epoch 00022: val_loss improved from 1.34153 to 1.33601, saving model to ./model/weights.hd5
# Epoch 23/120
# 25838/25838 [==============================] - 61s 2ms/step - loss: 1.3509 - accuracy: 0.4500 - val_loss: 1.3663 - val_accuracy: 0.4384
#
# Epoch 00023: val_loss did not improve from 1.33601
# Epoch 24/120
# 25838/25838 [==============================] - 62s 2ms/step - loss: 1.3389 - accuracy: 0.4579 - val_loss: 1.3600 - val_accuracy: 0.4441
#
# Epoch 00024: val_loss did not improve from 1.33601
# Epoch 25/120
# 25838/25838 [==============================] - 62s 2ms/step - loss: 1.3324 - accuracy: 0.4601 - val_loss: 1.2892 - val_accuracy: 0.4714
#
# Epoch 00025: val_loss improved from 1.33601 to 1.28922, saving model to ./model/weights.hd5
# Epoch 26/120
# 25838/25838 [==============================] - 61s 2ms/step - loss: 1.3120 - accuracy: 0.4735 - val_loss: 1.3049 - val_accuracy: 0.4697
#
# Epoch 00026: val_loss did not improve from 1.28922
# Epoch 27/120
# 25838/25838 [==============================] - 61s 2ms/step - loss: 1.2975 - accuracy: 0.4812 - val_loss: 1.2870 - val_accuracy: 0.4952
#
# Epoch 00027: val_loss improved from 1.28922 to 1.28700, saving model to ./model/weights.hd5
# Epoch 28/120
# 25838/25838 [==============================] - 61s 2ms/step - loss: 1.2795 - accuracy: 0.4911 - val_loss: 1.2634 - val_accuracy: 0.4964
#
# Epoch 00028: val_loss improved from 1.28700 to 1.26336, saving model to ./model/weights.hd5
# Epoch 29/120
# 25838/25838 [==============================] - 60s 2ms/step - loss: 1.2611 - accuracy: 0.4995 - val_loss: 1.2823 - val_accuracy: 0.4921
#
# Epoch 00029: val_loss did not improve from 1.26336
# Epoch 30/120
# 25838/25838 [==============================] - 61s 2ms/step - loss: 1.2509 - accuracy: 0.5076 - val_loss: 1.2620 - val_accuracy: 0.5099
#
# Epoch 00030: val_loss improved from 1.26336 to 1.26202, saving model to ./model/weights.hd5
# Epoch 31/120
# 25838/25838 [==============================] - 62s 2ms/step - loss: 1.2201 - accuracy: 0.5251 - val_loss: 1.2137 - val_accuracy: 0.5297
#
# Epoch 00031: val_loss improved from 1.26202 to 1.21366, saving model to ./model/weights.hd5
# Epoch 32/120
# 25838/25838 [==============================] - 62s 2ms/step - loss: 1.2060 - accuracy: 0.5350 - val_loss: 1.2330 - val_accuracy: 0.5228
#
# Epoch 00032: val_loss did not improve from 1.21366
# Epoch 33/120
# 25838/25838 [==============================] - 63s 2ms/step - loss: 1.1794 - accuracy: 0.5445 - val_loss: 1.2106 - val_accuracy: 0.5373
#
# Epoch 00033: val_loss improved from 1.21366 to 1.21056, saving model to ./model/weights.hd5
# Epoch 34/120
# 25838/25838 [==============================] - 62s 2ms/step - loss: 1.1536 - accuracy: 0.5562 - val_loss: 1.1767 - val_accuracy: 0.5582
#
# Epoch 00034: val_loss improved from 1.21056 to 1.17674, saving model to ./model/weights.hd5
# Epoch 35/120
# 25838/25838 [==============================] - 62s 2ms/step - loss: 1.1451 - accuracy: 0.5591 - val_loss: 1.1948 - val_accuracy: 0.5500
#
# Epoch 00035: val_loss did not improve from 1.17674
# Epoch 36/120
# 25838/25838 [==============================] - 63s 2ms/step - loss: 1.1335 - accuracy: 0.5713 - val_loss: 1.2370 - val_accuracy: 0.5390
#
# Epoch 00036: val_loss did not improve from 1.17674
# Epoch 37/120
# 25838/25838 [==============================] - 63s 2ms/step - loss: 1.1176 - accuracy: 0.5755 - val_loss: 1.1941 - val_accuracy: 0.5656
#
# Epoch 00037: val_loss did not improve from 1.17674
# Epoch 38/120
# 25838/25838 [==============================] - 63s 2ms/step - loss: 1.0851 - accuracy: 0.5884 - val_loss: 1.1906 - val_accuracy: 0.5690
#
# Epoch 00038: val_loss did not improve from 1.17674
# Epoch 39/120
# 25838/25838 [==============================] - 63s 2ms/step - loss: 1.0574 - accuracy: 0.5992 - val_loss: 1.1958 - val_accuracy: 0.5794
#
# Epoch 00039: val_loss did not improve from 1.17674
# Epoch 40/120
# 25838/25838 [==============================] - 63s 2ms/step - loss: 1.0371 - accuracy: 0.6125 - val_loss: 1.2602 - val_accuracy: 0.5341
#
# Epoch 00040: val_loss did not improve from 1.17674
# Epoch 41/120
# 25838/25838 [==============================] - 63s 2ms/step - loss: 1.0183 - accuracy: 0.6204 - val_loss: 1.1814 - val_accuracy: 0.5820
#
# Epoch 00041: val_loss did not improve from 1.17674
# Epoch 42/120
# 25838/25838 [==============================] - 63s 2ms/step - loss: 0.9942 - accuracy: 0.6298 - val_loss: 1.1837 - val_accuracy: 0.5873
#
# Epoch 00042: val_loss did not improve from 1.17674
# Epoch 43/120
# 25838/25838 [==============================] - 63s 2ms/step - loss: 0.9706 - accuracy: 0.6384 - val_loss: 1.1403 - val_accuracy: 0.5964
#
# Epoch 00043: val_loss improved from 1.17674 to 1.14031, saving model to ./model/weights.hd5
# Epoch 44/120
# 25838/25838 [==============================] - 57s 2ms/step - loss: 0.9499 - accuracy: 0.6475 - val_loss: 1.2085 - val_accuracy: 0.5985
#
# Epoch 00044: val_loss did not improve from 1.14031
# Epoch 45/120
# 25838/25838 [==============================] - 59s 2ms/step - loss: 0.9331 - accuracy: 0.6558 - val_loss: 1.2068 - val_accuracy: 0.5988
#
# Epoch 00045: val_loss did not improve from 1.14031
# Epoch 46/120
# 25838/25838 [==============================] - 60s 2ms/step - loss: 0.9278 - accuracy: 0.6578 - val_loss: 1.2079 - val_accuracy: 0.5909
#
# Epoch 00046: val_loss did not improve from 1.14031
# Epoch 47/120
# 25838/25838 [==============================] - 60s 2ms/step - loss: 0.9052 - accuracy: 0.6663 - val_loss: 1.2346 - val_accuracy: 0.5998
#
# Epoch 00047: val_loss did not improve from 1.14031
# Epoch 48/120
# 25838/25838 [==============================] - 60s 2ms/step - loss: 0.8719 - accuracy: 0.6828 - val_loss: 1.2177 - val_accuracy: 0.6002
#
# Epoch 00048: val_loss did not improve from 1.14031
# Epoch 49/120
# 25838/25838 [==============================] - 61s 2ms/step - loss: 0.8575 - accuracy: 0.6894 - val_loss: 1.2699 - val_accuracy: 0.5989
#
# Epoch 00049: val_loss did not improve from 1.14031
# Epoch 50/120
# 25838/25838 [==============================] - 61s 2ms/step - loss: 0.8473 - accuracy: 0.6948 - val_loss: 1.2340 - val_accuracy: 0.5997
#
# Epoch 00050: val_loss did not improve from 1.14031
# Epoch 51/120
# 25838/25838 [==============================] - 61s 2ms/step - loss: 0.8154 - accuracy: 0.7085 - val_loss: 1.2995 - val_accuracy: 0.6079
#
# Epoch 00051: val_loss did not improve from 1.14031
# Epoch 52/120
# 25838/25838 [==============================] - 61s 2ms/step - loss: 0.8008 - accuracy: 0.7109 - val_loss: 1.2690 - val_accuracy: 0.5938
#
# Epoch 00052: val_loss did not improve from 1.14031
# Epoch 53/120
# 25838/25838 [==============================] - 61s 2ms/step - loss: 0.7745 - accuracy: 0.7222 - val_loss: 1.3001 - val_accuracy: 0.6176
#
# Epoch 00053: val_loss did not improve from 1.14031
# Epoch 54/120
# 25838/25838 [==============================] - 61s 2ms/step - loss: 0.7578 - accuracy: 0.7299 - val_loss: 1.2641 - val_accuracy: 0.6193
#
# Epoch 00054: val_loss did not improve from 1.14031
# Epoch 55/120
# 25838/25838 [==============================] - 61s 2ms/step - loss: 0.7405 - accuracy: 0.7371 - val_loss: 1.3394 - val_accuracy: 0.6096
#
# Epoch 00055: val_loss did not improve from 1.14031
# Epoch 56/120
# 25838/25838 [==============================] - 60s 2ms/step - loss: 0.7230 - accuracy: 0.7463 - val_loss: 1.4062 - val_accuracy: 0.5825
#
# Epoch 00056: val_loss did not improve from 1.14031
# Epoch 57/120
# 25838/25838 [==============================] - 60s 2ms/step - loss: 0.6941 - accuracy: 0.7548 - val_loss: 1.3114 - val_accuracy: 0.6211
#
# Epoch 00057: val_loss did not improve from 1.14031
# Epoch 58/120
# 25838/25838 [==============================] - 61s 2ms/step - loss: 0.6814 - accuracy: 0.7593 - val_loss: 1.3776 - val_accuracy: 0.6245
#
# Epoch 00058: val_loss did not improve from 1.14031
# Epoch 59/120
# 25838/25838 [==============================] - 61s 2ms/step - loss: 0.6660 - accuracy: 0.7696 - val_loss: 1.3594 - val_accuracy: 0.6266
#
# Epoch 00059: val_loss did not improve from 1.14031
# Epoch 60/120
# 25838/25838 [==============================] - 61s 2ms/step - loss: 0.6497 - accuracy: 0.7768 - val_loss: 1.3881 - val_accuracy: 0.6262
#
# Epoch 00060: val_loss did not improve from 1.14031
# Epoch 61/120
# 25838/25838 [==============================] - 61s 2ms/step - loss: 0.6367 - accuracy: 0.7805 - val_loss: 1.3815 - val_accuracy: 0.6193
#
# Epoch 00061: val_loss did not improve from 1.14031
# Epoch 62/120
# 25838/25838 [==============================] - 61s 2ms/step - loss: 0.6240 - accuracy: 0.7822 - val_loss: 1.3328 - val_accuracy: 0.6192
#
# Epoch 00062: val_loss did not improve from 1.14031
# Epoch 63/120
# 25838/25838 [==============================] - 61s 2ms/step - loss: 0.6043 - accuracy: 0.7933 - val_loss: 1.4223 - val_accuracy: 0.6234
#
# Epoch 00063: val_loss did not improve from 1.14031
# Epoch 64/120
# 25838/25838 [==============================] - 61s 2ms/step - loss: 0.5836 - accuracy: 0.8011 - val_loss: 1.4449 - val_accuracy: 0.6257
#
# Epoch 00064: val_loss did not improve from 1.14031
# Epoch 65/120
# 25838/25838 [==============================] - 61s 2ms/step - loss: 0.5667 - accuracy: 0.8058 - val_loss: 1.3876 - val_accuracy: 0.6307
#
# Epoch 00065: val_loss did not improve from 1.14031
# Epoch 66/120
# 25838/25838 [==============================] - 61s 2ms/step - loss: 0.5586 - accuracy: 0.8107 - val_loss: 1.4943 - val_accuracy: 0.6296
#
# Epoch 00066: val_loss did not improve from 1.14031
# Epoch 67/120
# 25838/25838 [==============================] - 61s 2ms/step - loss: 0.5493 - accuracy: 0.8118 - val_loss: 1.4726 - val_accuracy: 0.6313
#
# Epoch 00067: val_loss did not improve from 1.14031
# Epoch 68/120
# 25838/25838 [==============================] - 61s 2ms/step - loss: 0.5253 - accuracy: 0.8200 - val_loss: 1.4918 - val_accuracy: 0.6308
#
# Epoch 00068: val_loss did not improve from 1.14031
# Epoch 69/120
# 25838/25838 [==============================] - 61s 2ms/step - loss: 0.5177 - accuracy: 0.8268 - val_loss: 1.5503 - val_accuracy: 0.6308
#
# Epoch 00069: val_loss did not improve from 1.14031
# Epoch 70/120
# 25838/25838 [==============================] - 61s 2ms/step - loss: 0.5135 - accuracy: 0.8284 - val_loss: 1.5532 - val_accuracy: 0.6327
#
# Epoch 00070: val_loss did not improve from 1.14031
# Epoch 71/120
# 25838/25838 [==============================] - 61s 2ms/step - loss: 0.4887 - accuracy: 0.8364 - val_loss: 1.5245 - val_accuracy: 0.6382
#
# Epoch 00071: val_loss did not improve from 1.14031
# Epoch 72/120
# 25838/25838 [==============================] - 61s 2ms/step - loss: 0.4829 - accuracy: 0.8400 - val_loss: 1.5513 - val_accuracy: 0.6393
#
# Epoch 00072: val_loss did not improve from 1.14031
# Epoch 73/120
# 25838/25838 [==============================] - 62s 2ms/step - loss: 0.4724 - accuracy: 0.8445 - val_loss: 1.6039 - val_accuracy: 0.6300
#
# Epoch 00073: val_loss did not improve from 1.14031
# Epoch 74/120
# 25838/25838 [==============================] - 62s 2ms/step - loss: 0.4650 - accuracy: 0.8456 - val_loss: 1.5379 - val_accuracy: 0.6373
#
# Epoch 00074: val_loss did not improve from 1.14031
# Epoch 75/120
# 25838/25838 [==============================] - 62s 2ms/step - loss: 0.4508 - accuracy: 0.8534 - val_loss: 1.6474 - val_accuracy: 0.6347
#
# Epoch 00075: val_loss did not improve from 1.14031
# Epoch 76/120
# 25838/25838 [==============================] - 62s 2ms/step - loss: 0.4392 - accuracy: 0.8551 - val_loss: 1.6234 - val_accuracy: 0.6373
#
# Epoch 00076: val_loss did not improve from 1.14031
# Epoch 77/120
# 25838/25838 [==============================] - 62s 2ms/step - loss: 0.4470 - accuracy: 0.8540 - val_loss: 1.5898 - val_accuracy: 0.6387
#
# Epoch 00077: val_loss did not improve from 1.14031
# Epoch 78/120
# 25838/25838 [==============================] - 62s 2ms/step - loss: 0.4267 - accuracy: 0.8606 - val_loss: 1.6328 - val_accuracy: 0.6412
# Epoch 00078: val_loss did not improve from 1.14031
# Epoch 79/120
# 25838/25838 [==============================] - 62s 2ms/step - loss: 0.4126 - accuracy: 0.8653 - val_loss: 1.6206 - val_accuracy: 0.6372
#
# Epoch 00079: val_loss did not improve from 1.14031
# Epoch 80/120
# 25838/25838 [==============================] - 62s 2ms/step - loss: 0.4000 - accuracy: 0.8669 - val_loss: 1.6231 - val_accuracy: 0.6402
#
# Epoch 00080: val_loss did not improve from 1.14031
# Epoch 81/120
# 25838/25838 [==============================] - 62s 2ms/step - loss: 0.3972 - accuracy: 0.8689 - val_loss: 1.6599 - val_accuracy: 0.6367
#
# Epoch 00081: val_loss did not improve from 1.14031
# Epoch 82/120
# 25838/25838 [==============================] - 62s 2ms/step - loss: 0.3775 - accuracy: 0.8765 - val_loss: 1.7294 - val_accuracy: 0.6421
#
# Epoch 00082: val_loss did not improve from 1.14031
# Epoch 83/120
# 25838/25838 [==============================] - 62s 2ms/step - loss: 0.3739 - accuracy: 0.8772 - val_loss: 1.7068 - val_accuracy: 0.6393
#
# Epoch 00083: val_loss did not improve from 1.14031
# Epoch 84/120
# 25838/25838 [==============================] - 63s 2ms/step - loss: 0.3708 - accuracy: 0.8822 - val_loss: 1.7478 - val_accuracy: 0.6415
#
# Epoch 00084: val_loss did not improve from 1.14031
# Epoch 85/120
# 25838/25838 [==============================] - 63s 2ms/step - loss: 0.3675 - accuracy: 0.8840 - val_loss: 1.7121 - val_accuracy: 0.6396
#
# Epoch 00085: val_loss did not improve from 1.14031
# Epoch 86/120
# 25838/25838 [==============================] - 63s 2ms/step - loss: 0.3513 - accuracy: 0.8876 - val_loss: 1.7685 - val_accuracy: 0.6420
#
# Epoch 00086: val_loss did not improve from 1.14031
# Epoch 87/120
# 25838/25838 [==============================] - 63s 2ms/step - loss: 0.3434 - accuracy: 0.8882 - val_loss: 1.8117 - val_accuracy: 0.6435
#
# Epoch 00087: val_loss did not improve from 1.14031
# Epoch 88/120
# 25838/25838 [==============================] - 63s 2ms/step - loss: 0.3427 - accuracy: 0.8893 - val_loss: 1.7579 - val_accuracy: 0.6413
#
# Epoch 00088: val_loss did not improve from 1.14031
# Epoch 89/120
# 25838/25838 [==============================] - 63s 2ms/step - loss: 0.3343 - accuracy: 0.8921 - val_loss: 1.7307 - val_accuracy: 0.6392
#
# Epoch 00089: val_loss did not improve from 1.14031
# Epoch 90/120
# 25838/25838 [==============================] - 63s 2ms/step - loss: 0.3243 - accuracy: 0.8969 - val_loss: 1.8977 - val_accuracy: 0.6461
#
# Epoch 00090: val_loss did not improve from 1.14031
# Epoch 91/120
# 25838/25838 [==============================] - 64s 2ms/step - loss: 0.3209 - accuracy: 0.8960 - val_loss: 1.9301 - val_accuracy: 0.6455
#
# Epoch 00091: val_loss did not improve from 1.14031
# Epoch 92/120
# 25838/25838 [==============================] - 64s 2ms/step - loss: 0.3112 - accuracy: 0.8981 - val_loss: 1.8257 - val_accuracy: 0.6426
#
# Epoch 00092: val_loss did not improve from 1.14031
# Epoch 93/120
# 25838/25838 [==============================] - 63s 2ms/step - loss: 0.3090 - accuracy: 0.8999 - val_loss: 1.8618 - val_accuracy: 0.6418
#
# Epoch 00093: val_loss did not improve from 1.14031
# Epoch 94/120
# 25838/25838 [==============================] - 63s 2ms/step - loss: 0.3064 - accuracy: 0.9013 - val_loss: 1.8670 - val_accuracy: 0.6444
#
# Epoch 00094: val_loss did not improve from 1.14031
# Epoch 95/120
# 25838/25838 [==============================] - 63s 2ms/step - loss: 0.2986 - accuracy: 0.9058 - val_loss: 1.8932 - val_accuracy: 0.6410
#
# Epoch 00095: val_loss did not improve from 1.14031
# Epoch 96/120
# 25838/25838 [==============================] - 63s 2ms/step - loss: 0.2971 - accuracy: 0.9061 - val_loss: 1.8884 - val_accuracy: 0.6446
#
# Epoch 00096: val_loss did not improve from 1.14031
# Epoch 97/120
# 25838/25838 [==============================] - 64s 2ms/step - loss: 0.2880 - accuracy: 0.9109 - val_loss: 1.9455 - val_accuracy: 0.6485
#
# Epoch 00097: val_loss did not improve from 1.14031
# Epoch 98/120
# 25838/25838 [==============================] - 64s 2ms/step - loss: 0.2815 - accuracy: 0.9084 - val_loss: 1.9625 - val_accuracy: 0.6485
#
# Epoch 00098: val_loss did not improve from 1.14031
# Epoch 99/120
# 25838/25838 [==============================] - 64s 2ms/step - loss: 0.2908 - accuracy: 0.9110 - val_loss: 1.9349 - val_accuracy: 0.6457
#
# Epoch 00099: val_loss did not improve from 1.14031
# Epoch 100/120
# 25838/25838 [==============================] - 64s 2ms/step - loss: 0.2791 - accuracy: 0.9101 - val_loss: 1.8802 - val_accuracy: 0.6485
#
# Epoch 00100: val_loss did not improve from 1.14031
# Epoch 101/120
# 25838/25838 [==============================] - 64s 2ms/step - loss: 0.2738 - accuracy: 0.9130 - val_loss: 1.9665 - val_accuracy: 0.6461
#
# Epoch 00101: val_loss did not improve from 1.14031
# Epoch 102/120
# 25838/25838 [==============================] - 64s 2ms/step - loss: 0.2713 - accuracy: 0.9138 - val_loss: 1.8973 - val_accuracy: 0.6457
#
# Epoch 00102: val_loss did not improve from 1.14031
# Epoch 103/120
# 25838/25838 [==============================] - 64s 2ms/step - loss: 0.2641 - accuracy: 0.9169 - val_loss: 1.9623 - val_accuracy: 0.6460
#
# Epoch 00103: val_loss did not improve from 1.14031
# Epoch 104/120
# 25838/25838 [==============================] - 64s 2ms/step - loss: 0.2583 - accuracy: 0.9185 - val_loss: 1.9878 - val_accuracy: 0.6475
#
# Epoch 00104: val_loss did not improve from 1.14031
# Epoch 105/120
# 25838/25838 [==============================] - 64s 2ms/step - loss: 0.2703 - accuracy: 0.9153 - val_loss: 1.9307 - val_accuracy: 0.6443
#
# Epoch 00105: val_loss did not improve from 1.14031
# Epoch 106/120
# 25838/25838 [==============================] - 64s 2ms/step - loss: 0.2604 - accuracy: 0.9169 - val_loss: 1.9517 - val_accuracy: 0.6455
#
# Epoch 00106: val_loss did not improve from 1.14031
# Epoch 107/120
# 25838/25838 [==============================] - 63s 2ms/step - loss: 0.2584 - accuracy: 0.9205 - val_loss: 1.9494 - val_accuracy: 0.6480
#
# Epoch 00107: val_loss did not improve from 1.14031
# Epoch 108/120
# 25838/25838 [==============================] - 63s 2ms/step - loss: 0.2557 - accuracy: 0.9202 - val_loss: 1.9827 - val_accuracy: 0.6488
#
# Epoch 00108: val_loss did not improve from 1.14031
# Epoch 109/120
# 25838/25838 [==============================] - 63s 2ms/step - loss: 0.2454 - accuracy: 0.9222 - val_loss: 1.9932 - val_accuracy: 0.6464
#
# Epoch 00109: val_loss did not improve from 1.14031
# Epoch 110/120
# 25838/25838 [==============================] - 62s 2ms/step - loss: 0.2416 - accuracy: 0.9238 - val_loss: 1.9618 - val_accuracy: 0.6463
#
# Epoch 00110: val_loss did not improve from 1.14031
# Epoch 111/120
# 25838/25838 [==============================] - 63s 2ms/step - loss: 0.2428 - accuracy: 0.9236 - val_loss: 1.9941 - val_accuracy: 0.6452
#
# Epoch 00111: val_loss did not improve from 1.14031
# Epoch 112/120
# 25838/25838 [==============================] - 63s 2ms/step - loss: 0.2380 - accuracy: 0.9233 - val_loss: 1.9734 - val_accuracy: 0.6485
#
# Epoch 00112: val_loss did not improve from 1.14031
# Epoch 113/120
# 25838/25838 [==============================] - 62s 2ms/step - loss: 0.2319 - accuracy: 0.9274 - val_loss: 2.0289 - val_accuracy: 0.6447
#
# Epoch 00113: val_loss did not improve from 1.14031
# Epoch 114/120
# 25838/25838 [==============================] - 62s 2ms/step - loss: 0.2295 - accuracy: 0.9276 - val_loss: 2.0270 - val_accuracy: 0.6481
#
# Epoch 00114: val_loss did not improve from 1.14031
# Epoch 115/120
# 25838/25838 [==============================] - 62s 2ms/step - loss: 0.2271 - accuracy: 0.9278 - val_loss: 2.0731 - val_accuracy: 0.6454
#
# Epoch 00115: val_loss did not improve from 1.14031
# Epoch 116/120
# 25838/25838 [==============================] - 62s 2ms/step - loss: 0.2219 - accuracy: 0.9292 - val_loss: 2.0989 - val_accuracy: 0.6498
#
# Epoch 00116: val_loss did not improve from 1.14031
# Epoch 117/120
# 25838/25838 [==============================] - 62s 2ms/step - loss: 0.2295 - accuracy: 0.9293 - val_loss: 2.0637 - val_accuracy: 0.6452
#
# Epoch 00117: val_loss did not improve from 1.14031
# Epoch 118/120
# 25838/25838 [==============================] - 62s 2ms/step - loss: 0.2258 - accuracy: 0.9311 - val_loss: 2.0607 - val_accuracy: 0.6492
#
# Epoch 00118: val_loss did not improve from 1.14031
# Epoch 119/120
# 25838/25838 [==============================] - 63s 2ms/step - loss: 0.2213 - accuracy: 0.9325 - val_loss: 2.0299 - val_accuracy: 0.6460
#
# Epoch 00119: val_loss did not improve from 1.14031
# Epoch 120/120
# 25838/25838 [==============================] - 62s 2ms/step - loss: 0.2237 - accuracy: 0.9305 - val_loss: 2.0378 - val_accuracy: 0.6497
#
# Epoch 00120: val_loss did not improve from 1.14031

# %% [markdown]
# ## 3. Testing the trained model

# %%
md.predictCNN(model, test_data, test_labels)
# Out:
# Accuracy score =  0.6480913903594316

# %% [markdown]
# ## 4. Saving the trained and tested model

# %%
md.saveCNN(model)
# Out:
# Saved successfully....

# %% [markdown]
# ## 5. Evaluating our trained model on Video/Images

# %%
# !python evaluateVideo.py
# Out:
# Loaded model from disk
# Using TensorFlow backend.
# T:\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# T:\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# T:\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# T:\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# T:\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# T:\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING:tensorflow:From T:\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# 2020-04-23 12:43:54.102484: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2
# 2020-04-23 12:43:54.720747: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: GeForce GTX 980M major: 5 minor: 2 memoryClockRate(GHz): 1.1265
# pciBusID: 0000:01:00.0
# totalMemory: 8.00GiB freeMemory: 6.71GiB
# 2020-04-23 12:43:54.721261: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2020-04-23 12:43:55.400436: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-04-23 12:43:55.400867: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2020-04-23 12:43:55.401112: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2020-04-23 12:43:55.401563: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 6458 MB memory) -> physical GPU (device: 0, name: GeForce GTX 980M, pci bus id: 0000:01:00.0, compute capability: 5.2)
# 2020-04-23 12:44:02.202355: I tensorflow/stream_executor/dso_loader.cc:152] successfully opened CUDA library cublas64_100.dll locally

# %% [markdown]
# #### Screenshot of video prediction output
# <img src="opss.png">

# %% [markdown]
# ##### Sad image output
# <img src="OutputImg/sadop.jpg">
#
# ##### Angry image output
# <img src="OutputImg/angryop.jpg">
#
# ##### Too happy image output
# <img src="OutputImg/happyop.jpg">
#
# ##### Confident image output
# <img src="OutputImg/confiop.jpg">
